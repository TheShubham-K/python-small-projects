# %%
hour = int(input("Starting time (hours): "))
mins = int(input("Starting time (minutes): "))
dura = int(input("Event duration (minutes): "))

# put your code here
hrs = hour + (dura // 60)
min = mins + (dura % 60)
minuend = min % 60
hrs = hrs + (min // 60)
hrs = hrs % 24
print("Event starts at: " + str(hour)+":"+str(mins)+
" and lasts "+str(dura)+" mins, it will end at "+ str(hrs)+":"+str(minuend))
# Out:
# Starting time (hours): 12
# Starting time (minutes): 15
# Event duration (minutes): 56
# Event starts at: 12:15 and lasts 56 mins, it will end at 13:11

# %%
123+0.0
# Out:
# 123.0

# %%
z=y=x=1
print(x, y, z, sep='*')
# Out:
# 1*1*1

# %%
x = 1
y = 2
z = x
x = y
y = z
print(x, y)
# Out:
# 2 1

# %%
print(type(0o))
# Out:
#   File "<ipython-input-8-ad5ea7b22cfd>", line 1
#     print(type(0o))
#                 ^
# SyntaxError: invalid token

# %%
1 /2+3 // 3+4 ** 2
# Out:
# 17.5

# %%
2 + 3 * 5.
# Out:
# 17.0

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-724ba28f4a9a> in <module>
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True
# Out:
# True

# %%
12/56
# Out:
# 0.21428571428571427

# %%
1/1
# Out:
# 1.0

# %%
x = int(input())
y = int(input())
# x = x / y
# y = y / x
print(x + y)
# Out:
# 2
# 4
# 6

# %%
print(0)
# Out:
# 0

# %%
x = int(input())
y = int(input())
x = x % y
x = x % y
y = y % x
print(y)
# Out:
# 11
# 4
# 1

# %%
flower = input("Enter a flower name: ")


if flower == flower.upper():
    print("Yes - Spathiphyllum is the best plant ever!")
elif flower == "spathiphyllum":
    print("No, I want a big Spathiphyllum!")
else:
    print("Spathiphyllum! Not "+ flower)
# Out:
# Enter a flower name: lilly
# No, I want a big Spathiphyllum!

# %%
income = float(input("Enter the annual income: "))

x = 85528
# Put your code here.

if income > x:
    surplus = income - x
    tax = (14839) + (0.32*surplus)
else:
    tax = 0.18*income - 556 

tax = round(tax, 0)
print("The tax is:", tax, "thalers")
# Out:
# Enter the annual income: 5000
# The tax is: 344.0 thalers

# %%
year = int(input("Enter a year: "))

#
# Put your code here.

if (year % 400) == 0  and ((year % 4) == 0 and  ((year % 100) != 0 or (year % 400) == 0)):
    print("Leap Year!!!!")
elif year % 400 != 0: 
    print("not in Geogrion Calender!!")
else:
    print("Common Year")
# Out:
# Enter a year: 5000
# not in Geogrion Calender!!

# %%
# we will store the current largest number here
largest_number = -999999999

# input the first value
number = int(input("Enter a number or type -1 to stop: "))

# if the number is not equal to -1, we will continue
while number != -1:
    # is number larger than largest_number?
    if number > largest_number:
        # yes, update largest_number
        largest_number = number
    # input the next number
    number = int(input("Enter a number or type -1 to stop: "))

# print the largest number
print("The largest number is:", largest_number)
# Out:
# Enter a number or type -1 to stop: 59595955959
# Enter a number or type -1 to stop: 45454545
# Enter a number or type -1 to stop: 59959595
# Enter a number or type -1 to stop: 56656
# Enter a number or type -1 to stop: 545454
# Enter a number or type -1 to stop: -1
# The largest number is: 59595955959

# %%
# A program that reads a sequence of numbers
# and counts how many numbers are even and how many are odd.
# The program terminates when zero is entered.

odd_numbers = 0
even_numbers = 0

# read the first number
number = int(input("Enter a number or type 0 to stop: "))

# 0 terminates execution
while number != 0:
    # check if the number is odd
    if number % 2 == 1:
        # increase the odd_numbers counter
        odd_numbers += 1
    else:
        # increase the even_numbers counter
        even_numbers += 1
    # read the next number
    number = int(input("Enter a number or type 0 to stop: "))

# print results
print("Odd numbers count:", odd_numbers)
print("Even numbers count:", even_numbers)
# Out:
# Enter a number or type 0 to stop: 5656
# Enter a number or type 0 to stop: 4545
# Enter a number or type 0 to stop: 1
# Enter a number or type 0 to stop: 0
# Odd numbers count: 2
# Even numbers count: 1

# %%
# A junior magician has picked a secret number. He has hidden it in a variable named secret_number. 
# He wants everyone who run his program to play the Guess the secret number game, and guess what 
# number he has picked for them.


secret_number = 777


number = int(input("Enter a Number: "))

while number != secret_number:
    print("Ha ha! You're stuck in my loop!")
    number = int(input("Enter a Number: "))

print(
"""
+================================+
| Welcome to my game, muggle!    |
| Enter an integer number        |
| and guess what number I've     |
| picked for you.                |
| So, what is the secret number? |
+================================+
""")
print("Well done, muggle! YOu are free now..")
# Out:
# Enter a Number: 45
# Ha ha! You're stuck in my loop!
# Enter a Number: 89
# Ha ha! You're stuck in my loop!
# Enter a Number: 78
# Ha ha! You're stuck in my loop!
# Enter a Number: 56
# Ha ha! You're stuck in my loop!
# Enter a Number: 12
# Ha ha! You're stuck in my loop!
# Enter a Number: 777
#
# +================================+
# | Welcome to my game, muggle!    |
# | Enter an integer number        |
# | and guess what number I've     |
# | picked for you.                |
# | So, what is the secret number? |
# +================================+
#
# Well done, muggle! YOu are free now..

# %%
pow = 1
for i in range(17):
    print("2 to the power of", i, " is ", pow)
    pow *= 2
# Out:
# 2 to the power of 0  is  1
# 2 to the power of 1  is  2
# 2 to the power of 2  is  4
# 2 to the power of 3  is  8
# 2 to the power of 4  is  16
# 2 to the power of 5  is  32
# 2 to the power of 6  is  64
# 2 to the power of 7  is  128
# 2 to the power of 8  is  256
# 2 to the power of 9  is  512
# 2 to the power of 10  is  1024
# 2 to the power of 11  is  2048
# 2 to the power of 12  is  4096
# 2 to the power of 13  is  8192
# 2 to the power of 14  is  16384
# 2 to the power of 15  is  32768
# 2 to the power of 16  is  65536

# %%
import time

# Write a for loop that counts to five.
    # Body of the loop - print the loop iteration number and the word "Mississippi".
    # Body of the loop - use: time.sleep(1)

# Write a print function with the final message.
for i in range(1, 6):
    print(i, " Mississppi")
    time.sleep(1)
# Out:
# 1  Mississppi
# 2  Mississppi
# 3  Mississppi
# 4  Mississppi
# 5  Mississppi

# %%
# break - example

print("The break instruction:")
for i in range(1, 6):
    if i == 3:
        break
    print("Inside the loop.", i)
print("Outside the loop.")


# continue - example

print("\nThe continue instruction:")
for i in range(1, 6):
    if i == 3:
        continue
    print("Inside the loop.", i)
print("Outside the loop.")
# Out:
# The break instruction:
# Inside the loop. 1
# Inside the loop. 2
# Outside the loop.
#
# The continue instruction:
# Inside the loop. 1
# Inside the loop. 2
# Inside the loop. 4
# Inside the loop. 5
# Outside the loop.

# %%
largestNumber = -99999999
counter = 0

while True:
    number = int(input("Enter a number or type -1 to end program: "))
    if number == -1:
        break
    counter += 1
    if number > largestNumber:
        largestNumber = number

if counter != 0:
    print("The largest number is", largestNumber)
else:
    print("You haven't entered any number.")
# Out:
# Enter a number or type -1 to end program: 9
# Enter a number or type -1 to end program: 6
# Enter a number or type -1 to end program: 54
# Enter a number or type -1 to end program: 5
# Enter a number or type -1 to end program: 2
# Enter a number or type -1 to end program: 1
# Enter a number or type -1 to end program: 6
# Enter a number or type -1 to end program: 6
# Enter a number or type -1 to end program: 3
# Enter a number or type -1 to end program: -1
# The largest number is 54

# %%
# With Contiune
largestNumber = -99999999
counter = 0

number = int(input("Enter a number or type -1 to end program: "))

while number != -1:
    if number == -1:
        continue
    counter += 1

    if number > largestNumber:
        largestNumber = number
    number = int(input("Enter a number or type -1 to end program: "))

if counter:
    print("The largest number is", largestNumber)
else:
    print("You haven't entered any number.")
# Out:
# Enter a number or type -1 to end program: 56
# Enter a number or type -1 to end program: 45
# Enter a number or type -1 to end program: -1
# The largest number is 56

# %%
# Break the loop
word = input("Enter the Secret Word")
secret_word = "chupacabra"

while word != secret_word:
    print("Please try Again....")
    word = input("Enter the Secret Word")
    if word == secret_word:
        break
    
print("You've successfully left the loop")
# Out:
# Enter the Secret Wordchupacabra
# You've successfully left the loop

# %%
counter = 5
while counter != 0:
    print("Inside the loop.", counter)
    counter -= 1
print("Outside the loop.", counter)
# Out:
# Inside the loop. 5
# Inside the loop. 4
# Inside the loop. 3
# Inside the loop. 2
# Inside the loop. 1
# Outside the loop. 0

# %%
# Joining Letters "wordWithoutVowels"..
# Prompt the user to enter a word
word = input("Enter a word: ")
# and assign it to the userWord variable.
userWord = word.upper()
wordWithoutVowels = ""

for letter in userWord:
    # Complete the body of the for loop.
    if letter in ['A', 'E', 'I', 'O', 'U']:
        continue
    wordWithoutVowels += letter
print(wordWithoutVowels)
# Out:
# Enter a word: Gregory
# GRGRY

# %%
word = input("Enter a word: ")
# and assign it to the userWord variable.
userWord = word.upper()
wordWithoutVowels = ""

for letter in userWord:
    # Complete the body of the for loop.
    if letter in ['A', 'E', 'I', 'O', 'U']:
        continue
    wordWithoutVowels += letter
    print(wordWithoutVowels)
# Out:
# Enter a word: Shubham
# S
# SH
# SHB
# SHBH
# SHBHM

# %% [markdown]
# A simple Pyramid made out of blocks.
# ![image.png](attachment:image.png)

# %%
blocks = int(input("Enter the number of blocks: "))

# Write your code here.
height = 0
inlayer = 1

while inlayer<= blocks:
    height += 1
    blocks -= inlayer
    inlayer += 1

print("The height of the pyramid:", height)
# Out:
# Enter the number of blocks: 56
# The height of the pyramid: 10

# %% [markdown]
# Write a Python program where you take any positive integer n, if n is even, divide it by 2 to get n / 2. If n is odd, multiply it by 3 and add 1 to obtain 3n + 1. Repeat the process until you reach 1.(collatz sequence)
# ![image.png](attachment:image.png)
# http://localhost:8888/files/python-23.png

# %%
def collatz_sequence(x):
    num_seq = []
    step = 0
    
    if x < 1:
        return []
    while x > 1:
        if x % 2 == 0:
            x = x / 2
        else:
            x = 3*x + 1
#     Added line
        num_seq.append(x)
        step += 1
    print("Steps = ",step)
    return num_seq

print(collatz_sequence(12))
print(collatz_sequence(14))
print(collatz_sequence(15))
print(collatz_sequence(16))
print(collatz_sequence(17))
print(collatz_sequence(1023))
print(collatz_sequence(1200))
# Out:
# Steps =  9
# [6.0, 3.0, 10.0, 5.0, 16.0, 8.0, 4.0, 2.0, 1.0]
# Steps =  17
# [7.0, 22.0, 11.0, 34.0, 17.0, 52.0, 26.0, 13.0, 40.0, 20.0, 10.0, 5.0, 16.0, 8.0, 4.0, 2.0, 1.0]
# Steps =  17
# [46, 23.0, 70.0, 35.0, 106.0, 53.0, 160.0, 80.0, 40.0, 20.0, 10.0, 5.0, 16.0, 8.0, 4.0, 2.0, 1.0]
# Steps =  4
# [8.0, 4.0, 2.0, 1.0]
# Steps =  12
# [52, 26.0, 13.0, 40.0, 20.0, 10.0, 5.0, 16.0, 8.0, 4.0, 2.0, 1.0]
# Steps =  62
# [3070, 1535.0, 4606.0, 2303.0, 6910.0, 3455.0, 10366.0, 5183.0, 15550.0, 7775.0, 23326.0, 11663.0, 34990.0, 17495.0, 52486.0, 26243.0, 78730.0, 39365.0, 118096.0, 59048.0, 29524.0, 14762.0, 7381.0, 22144.0, 11072.0, 5536.0, 2768.0, 1384.0, 692.0, 346.0, 173.0, 520.0, 260.0, 130.0, 65.0, 196.0, 98.0, 49.0, 148.0, 74.0, 37.0, 112.0, 56.0, 28.0, 14.0, 7.0, 22.0, 11.0, 34.0, 17.0, 52.0, 26.0, 13.0, 40.0, 20.0, 10.0, 5.0, 16.0, 8.0, 4.0, 2.0, 1.0]
# Steps =  18
# ...

# %%
text = "OpenEDG Python Institute"
for letter in text:
    if letter == "p":
        break
    print(letter, end ="")
# Out:
# O

# %%
text = "pyxpyxpyx"
for letter in  text:
    if letter == "x":
        continue
    print(letter, end="")
# Out:
# pypypy

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Dangerous
while(True):
    print("Stuck in an Infinity loop.")

# %%
for ch in "john.smith@pythoninstitute.org":
    if ch == "@":
        break
    print(ch, end="")
# Out:
# john.smith

# %%
for digit in "0165031806510":
    if digit == "0":
        print("x", end="")
        continue
    print(digit, end="")
# Out:
# x165x318x651x

# %%
# Logical operators
x = 1
y = 0

z = ((x == y) and (x == y)) or not(x == y)
print(not(z))
# Out:
# False

# %%
x = 4 #(0100)
y = 1 #(0001)

a = x & y
b = x | y
c = ~x
d = x ^ 5
e = x >> 2
f = x << 2

print(a, b, c, d, e, f)
# Out:
# 0 5 -5 1 1 16

# %%
# Removing elements from a list

numbers = [10, 5, 7, 2, 1]
print("Original list content:", numbers) # printing original list content

numbers[0] = 111
print("\nPrevious list content:", numbers) # printing previous list content

numbers[1] = numbers[4] # copying value of the fifth element to the second
print("Previous list content:", numbers) # printing previous list content

print("\nList's length:", len(numbers)) # printing previous list length

###

del numbers[1] # removing the second element from the list
print("New list's length:", len(numbers)) # printing new list length
print("\nNew list content:", numbers) # printing current list content

###
# Out:
# Original list content: [10, 5, 7, 2, 1]
#
# Previous list content: [111, 5, 7, 2, 1]
# Previous list content: [111, 1, 7, 2, 1]
#
# List's length: 5
# New list's length: 4
#
# New list content: [111, 7, 2, 1]

# %%
hatList = [1, 2, 3, 4, 5]  # This is an existing list of numbers hidden in the hat.
mid = int(len(hatList)/2)

# Step 1: write a line of code that prompts the user
MiddleNum = int(input("Enter the New Middle Number: "))
# to replace the middle number with an integer number entered by the user.
hatList[mid] = MiddleNum
print(hatList)
# Step 2: write a line of code here that removes the last element from the list.
del hatList[-1]
# Step 3: write a line of code here that prints the length of the existing list.
print(len(hatList))
print(hatList)
# Out:
# Enter the New Middle Number: 5
# [1, 2, 5, 4, 5]
# 4
# [1, 2, 5, 4]

# %%
# add the elements of the list 
myList = [10, 1, 8, 3, 5]
total = 0

for i in range(len(myList)):
    total += myList[i]

print(total)
# Out:
# 27

# %%
# Python offers a more convenient way of doing the swapping
variable1 = 1
variable2 = 2

variable1, variable2 = variable2, variable1
print(variable1, variable2)
# Out:
# 2 1

# %%
# Some more Examples
myList = [10, 1, 8, 3, 5]

myList[0], myList[4] = myList[4], myList[0]
myList[1], myList[3] = myList[3], myList[1]

print(myList)
# Out:
# [5, 3, 8, 1, 10]

# %%
# Same as above but with for loop
myList = [10, 1, 8, 3, 5]
length = len(myList)

for i in range(length // 2):
    myList[i], myList[length - i - 1] = myList[length - i - 1], myList[i]

print(myList)
# Out:
# [5, 3, 8, 1, 10]

# %%
# step 1
beatles = []
print("Step 1:", beatles)

# step 2
beatles.append("John Lennon")
beatles.append("Paul McCartney")
beatles.append("George Harrison")
print("Step 2:", beatles)

# step 3
for name in range(len(beatles)-1):
    name = input("Enter the to be added in the list: ")
    beatles.append(name)
print("Step 3:", beatles)
# step 4
del beatles[-2:] 
print("Step 4:", beatles)
# step 5
beatles.insert(0, "Ringo Starr")
print("Step 5:", beatles)

# testing list legth
print("The Fab", len(beatles))
# Out:
# Step 1: []
# Step 2: ['John Lennon', 'Paul McCartney', 'George Harrison']
# Enter the to be added in the list: Stu Sutcliffe
# Enter the to be added in the list: Pete Best
# Step 3: ['John Lennon', 'Paul McCartney', 'George Harrison', 'Stu Sutcliffe', 'Pete Best']
# Step 4: ['John Lennon', 'Paul McCartney', 'George Harrison']
# Step 5: ['Ringo Starr', 'John Lennon', 'Paul McCartney', 'George Harrison']
# The Fab 4
